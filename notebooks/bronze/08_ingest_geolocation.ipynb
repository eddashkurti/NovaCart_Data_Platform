# %%
from pyspark.sql.types import (
    DoubleType,
    IntegerType,
    StringType,
    StructField,
    StructType,
)

from src.bronze_ingestion import ingest_csv_to_delta


geolocation_schema = StructType(
    [
        StructField("geolocation_zip_code_prefix", IntegerType(), True),
        StructField("geolocation_lat", DoubleType(), True),
        StructField("geolocation_lng", DoubleType(), True),
        StructField("geolocation_city", StringType(), True),
        StructField("geolocation_state", StringType(), True),
    ]
)


geolocation_bronze_df = ingest_csv_to_delta(
    dataset_name="geolocation",
    source_path=(
        "abfss://raw@stnovacartdev.dfs.core.windows.net/"
        "olist/olist_geolocation_dataset.csv"
    ),
    destination_path=(
        "abfss://bronze@stnovacartdev.dfs.core.windows.net/"
        "olist/geolocation"
    ),
    expected_columns={
        "geolocation_zip_code_prefix",
        "geolocation_lat",
        "geolocation_lng",
        "geolocation_city",
        "geolocation_state",
    },
    source_schema=geolocation_schema,
    spark_session=spark,
)

display(geolocation_bronze_df.limit(10))
