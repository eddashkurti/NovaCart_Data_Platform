# %%
from src.bronze_ingestion import ingest_csv_to_delta


order_payments_bronze_df = ingest_csv_to_delta(
    dataset_name="order_payments",
    source_path=(
        "abfss://raw@stnovacartdev.dfs.core.windows.net/"
        "olist/olist_order_payments_dataset.csv"
    ),
    destination_path=(
        "abfss://bronze@stnovacartdev.dfs.core.windows.net/"
        "olist/order_payments"
    ),
    expected_columns={
        "order_id",
        "payment_sequential",
        "payment_type",
        "payment_installments",
        "payment_value",
    },
    spark_session=spark,
)

display(order_payments_bronze_df.limit(10))
